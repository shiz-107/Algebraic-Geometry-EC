# %% [markdown]
# <a href="https://colab.research.google.com/github/shiz-107/Algebraic-Geometry-EC/blob/main/Copy_of_current_mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
j = complex(0, 1)
p = 11
a = 3+2j
b = 9+5j
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i**3 + a*i**2 + i+b )
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y= (k**2).real%p + ((k**2).imag%p)*j
                if X == Y:
                    R = (i, k)
                    print(R)
                    count += 1  # Increment the counter
                    break
            else:
                    continue
            break
print(count)
# Out:
# (1j, (3+6j))
# (4j, (3+2j))
# (5j, 0j)
# (6j, (1+10j))
# (7j, (4+0j))
# (8j, (2+0j))
# (10j, (3+6j))
# ((1+0j), (2+10j))
# ((1+1j), (4+10j))
# ((1+2j), (2+0j))
# ((1+4j), (4+9j))
# ((1+6j), (3+9j))
# ((1+7j), (4+4j))
# ((1+8j), (5+3j))
# ((2+5j), (1+9j))
# ((2+6j), (3+3j))
# ((2+7j), 2j)
# ((2+8j), (4+3j))
# ((2+9j), (3+3j))
# ((3+0j), (4+7j))
# ((3+1j), (3+0j))
# ((3+2j), (4+0j))
# ((3+3j), (2+7j))
# ((3+4j), (5+10j))
# ((3+6j), 3j)
# ((3+10j), (1+10j))
# ((4+1j), (3+5j))
# ((4+2j), (1+1j))
# ((4+5j), (3+3j))
# ((4+6j), 4j)
# ((4+7j), (4+1j))
# ((4+8j), (5+8j))
# ((4+9j), (1+6j))
# ((5+0j), (4+0j))
# ((5+1j), (3+8j))
# ((5+4j), (1+10j))
# ((5+5j), (5+8j))
# ((5+8j), (5+1j))
# ((5+9j), (3+5j))
# ((5+10j), (1+7j))
# ((6+0j), (3+0j))
# ((6+2j), (1+5j))
# ((6+3j), (4+2j))
# ((6+4j), 4j)
# ((6+5j), 3j)
# ((6+6j), (4+4j))
# ((6+7j), (1+1j))
# ((7+0j), (3+8j))
# ((7+1j), (2+1j))
# ((7+8j), (3+8j))
# ((7+9j), (3+7j))
# ((7+10j), (2+0j))
# ((8+0j), (2+3j))
# ((8+2j), (2+4j))
# ((8+4j), 2j)
# ((8+5j), (1+4j))
# ((8+6j), (1+2j))
# ((8+9j), (3+6j))
# ((8+10j), (4+7j))
# ((9+0j), (1+1j))
# ((9+1j), 0j)
# ((9+2j), (2+8j))
# ((9+5j), (5+3j))
# ((9+7j), (5+3j))
# ((9+9j), 2j)
# ((9+10j), 4j)
# ((10+2j), (4+8j))
# ((10+3j), 0j)
# ((10+4j), (3+4j))
# ((10+7j), (5+8j))
# ((10+8j), (3+0j))
# ((10+9j), 3j)
# ((10+10j), (3+5j))
# 73

# %%
# all ordersss
j = complex(0, 1)
p = 11
a = 3+2j
b = 9+5j
R = []

for m in range(p):
    for n in range(p):
        i = m + n * j

        Z = (i ** 3 + a * i ** 2 + i * 1 +b)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j

        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j

                z = (k ** 2)
                real_part = z.real % p
                imaginary_part = z.imag % p
                Y = real_part + imaginary_part * 1j

                if X == Y:
                    R.append((i, k))

# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope ** 2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points

target_order = 2
points_with_order = find_points_with_order(target_order)

print(f"Points with order {target_order}:")
for P in points_with_order:
    print(P)
# Out:
# Points with order 2:
# (5j, 0j)
# ((9+1j), 0j)
# ((10+3j), 0j)

# %%
# poins doubling , addition , order, nP, order chk
j = complex(0, 1)
A = 3+2j
b = 9+5j
p = 11 # the field size
infinity = None

# Define a function to add two points on the curve
def point_addition(P, Q):
    # Point at infinity
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * A * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope ** 2 - A - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

P = ((6+2j), (1+5j))
Q = P
point_addition(P,Q)
for i in range(121):
  Q=point_addition(P,Q)
  print(Q)

# %%
# Points addition
# Define the parameters of the elliptic curve E : y^2=x^3+Ax+x over F_431[j]
j = complex(0,1)
A =3+2j
p = 431 # the field size


# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P



    if P != Q:

        num = Q[1] - P[1]
        num_prime = num.real%p + num.imag%p*j

        den = Q[0] - P[0]
        den_prime = den.real%p + den.imag%p*j
        conj_den = den_prime.real%p + (p-den_prime.imag)%p*j
        ab = ((den_prime.real)**2+(den_prime.imag)**2)%p

        def find_inverse(element, mod):
          if element == 0:
            return None

          # Apply the extended Euclidean algorithm
          a, b = mod, element
          x, y = 0, 1
          while b != 0:
               quotient = a // b
               a, b = b, a - quotient * b
               x, y = y, x - quotient * y

           # Ensure the inverse is positive
          inverse = x % mod
          if inverse < 0:
               inverse += mod

          return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)
        print(inverse)
        den_double = conj_den*inverse
        den_triple = den_double.real%p + den_double.imag%p*j
        slope_prime = num_prime*den_triple
        slope = slope_prime.real%p + slope_prime.imag%p*j
        print(slope)


    Rx = slope**2 - A - P[0] - Q[0]
    Rx_prime = complex(Rx.real%p , Rx.imag%p)
    print(Rx_prime)
    Ry = -(P[1] + slope * (Rx_prime - P[0]) )
    Ry_prime = complex(Ry.real%p , Ry.imag%p)
    return (Rx_prime, Ry_prime)



# Test point addition
P=(1j, (97+150j))
Q=(2j, (209+396j))
R=point_addition(P,Q)
print(R)

# %%
j = complex(0, 1)
p = 11
a = 0
b = 0
d = 1
c = 3 + 2j
e = 9 + 5j
P = ((1+6j), (8+2j))
f = 3 * P[0] ** 2 + 2 * c * P[0] + d
f_prime = (f.real % p) + (f.imag % p) * j
print(f"P = {P}, f(P) = {f_prime}")
g = -2 * P[1]
g_prime = (g.real % p) + (g.imag % p) * j
print(f"P = {P}, g(P) = {g_prime}")
# Out:
# P = ((1+6j), (8+2j)), f(P) = (10+10j)
# P = ((1+6j), (8+2j)), g(P) = (6+7j)

# %%
j = complex(0, 1)
p = 11
a = 0
b = 0
d = 1
c = 3 + 2j
e = 9 + 5j
R = []
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + c * i ** 2 + i + e)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y = (k ** 2).real % p + ((k ** 2).imag % p) * j
                if X == Y:
                  R.append((i, k))
                  count+=1
                  break
            else:
                    continue
            break
for P in R:
    f = 3 * P[0] ** 2 + 2 * c * P[0] + d
    f_prime = (f.real % p) + (f.imag % p) * j
    g = -2 * P[1]
    g_prime = (g.real % p) + (g.imag % p) * j
    print(f"P = {P},f(P) = {f_prime}, g(p) = {g_prime}")
print(count)
# Out:
# P = (1j, (3+6j)),f(P) = (5+6j), g(p) = (5+10j)
# P = (4j, (3+2j)),f(P) = (3+2j), g(p) = (5+7j)
# P = (5j, 0j),f(P) = (5+8j), g(p) = 0j
# P = (6j, (1+10j)),f(P) = (1+3j), g(p) = (9+2j)
# P = (7j, (4+0j)),f(P) = (2+9j), g(p) = (3+0j)
# P = (8j, (2+0j)),f(P) = (8+4j), g(p) = (7+0j)
# P = (10j, (3+6j)),f(P) = (2+5j), g(p) = (5+10j)
# P = ((1+0j), (2+10j)),f(P) = (10+4j), g(p) = (7+2j)
# P = ((1+1j), (4+10j)),f(P) = (3+5j), g(p) = (3+2j)
# P = ((1+2j), (2+0j)),f(P) = (1+6j), g(p) = (7+0j)
# P = ((1+4j), (4+9j)),f(P) = (1+8j), g(p) = (3+4j)
# P = ((1+6j), (3+9j)),f(P) = (10+10j), g(p) = (5+4j)
# P = ((1+7j), (4+4j)),f(P) = 0j, g(p) = (3+3j)
# P = ((1+8j), (5+3j)),f(P) = (6+1j), g(p) = (1+5j)
# P = ((2+5j), (1+9j)),f(P) = (7+10j), g(p) = (9+4j)
# P = ((2+6j), (3+3j)),f(P) = (3+6j), g(p) = (5+5j)
# P = ((2+7j), 2j),f(P) = (4+2j), g(p) = 7j
# P = ((2+8j), (4+3j)),f(P) = (10+9j), g(p) = (3+5j)
# P = ((2+9j), (3+3j)),f(P) = (10+5j), g(p) = (5+5j)
# P = ((3+0j), (4+7j)),f(P) = (2+1j), g(p) = (3+8j)
# P = ((3+1j), (3+0j)),f(P) = (6+3j), g(p) = (5+0j)
# P = ((3+2j), (4+0j)),f(P) = (4+5j), g(p) = (3+0j)
# P = ((3+3j), (2+7j)),f(P) = (7+7j), g(p) = (7+8j)
# P = ((3+4j), (5+10j)),f(P) = (4+9j), g(p) = (1+2j)
# P = ((3+6j), 3j),f(P) = (2+2j), g(p) = 5j
# P = ((3+10j), (1+10j)),f(P) = (3+10j), g(p) = (9+2j)
# P = ((4+1j), (3+5j)),f(P) = 2j, g(p) = (5+1j)
# P = ((4+2j), (1+1j)),f(P) = (9+10j), g(p) = (9+9j)
# P = ((4+5j), (3+3j)),f(P) = 1j, g(p) = (5+5j)
# P = ((4+6j), 4j),f(P) = (7+9j), g(p) = 3j
# P = ((4+7j), (4+1j)),f(P) = (8+6j), g(p) = (3+9j)
# P = ((4+8j), (5+8j)),f(P) = (3+3j), g(p) = (1+6j)
# P = ((4+9j), (1+6j)),f(P) = (3+0j), g(p) = (9+10j)
# P = ((5+0j), (4+0j)),f(P) = (7+9j), g(p) = (3+0j)
# P = ((5+1j), (3+8j)),f(P) = 1j, g(p) = (5+6j)
# P = ((5+4j), (1+10j)),f(P) = (9+10j), g(p) = (9+2j)
# P = ((5+5j), (5+8j)),f(P) = 2j, g(p) = (1+6j)
# P = ((5+8j), (5+1j)),f(P) = (3+0j), g(p) = (1+9j)
# P = ((5+9j), (3+5j)),f(P) = (3+3j), g(p) = (5+1j)
# P = ((5+10j), (1+7j)),f(P) = (8+6j), g(p) = (9+8j)
# P = ((6+0j), (3+0j)),f(P) = (2+2j), g(p) = (5+0j)
# P = ((6+2j), (1+5j)),f(P) = (4+9j), g(p) = (9+1j)
# P = ((6+3j), (4+2j)),f(P) = (7+7j), g(p) = (3+7j)
# P = ((6+4j), 4j),f(P) = (4+5j), g(p) = 3j
# P = ((6+5j), 3j),f(P) = (6+3j), g(p) = 5j
# P = ((6+6j), (4+4j)),f(P) = (2+1j), g(p) = (3+3j)
# P = ((6+7j), (1+1j)),f(P) = (3+10j), g(p) = (9+9j)
# P = ((7+0j), (3+8j)),f(P) = (3+6j), g(p) = (5+6j)
# P = ((7+1j), (2+1j)),f(P) = (7+10j), g(p) = (7+9j)
# P = ((7+8j), (3+8j)),f(P) = (10+5j), g(p) = (5+6j)
# P = ((7+9j), (3+7j)),f(P) = (10+9j), g(p) = (5+8j)
# P = ((7+10j), (2+0j)),f(P) = (4+2j), g(p) = (7+0j)
# P = ((8+0j), (2+3j)),f(P) = (10+10j), g(p) = (7+5j)
# P = ((8+2j), (2+4j)),f(P) = (1+8j), g(p) = (7+3j)
# P = ((8+4j), 2j),f(P) = (1+6j), g(p) = 7j
# P = ((8+5j), (1+4j)),f(P) = (3+5j), g(p) = (9+3j)
# P = ((8+6j), (1+2j)),f(P) = (10+4j), g(p) = (9+7j)
# P = ((8+9j), (3+6j)),f(P) = (6+1j), g(p) = (5+10j)
# P = ((8+10j), (4+7j)),f(P) = 0j, g(p) = (3+8j)
# P = ((9+0j), (1+1j)),f(P) = (1+3j), g(p) = (9+9j)
# P = ((9+1j), 0j),f(P) = (5+8j), g(p) = 0j
# P = ((9+2j), (2+8j)),f(P) = (3+2j), g(p) = (7+6j)
# P = ((9+5j), (5+3j)),f(P) = (5+6j), g(p) = (1+5j)
# P = ((9+7j), (5+3j)),f(P) = (2+5j), g(p) = (1+5j)
# P = ((9+9j), 2j),f(P) = (8+4j), g(p) = 7j
# P = ((9+10j), 4j),f(P) = (2+9j), g(p) = 3j
# P = ((10+2j), (4+8j)),f(P) = 7j, g(p) = (3+6j)
# P = ((10+3j), 0j),f(P) = (3+7j), g(p) = 0j
# P = ((10+4j), (3+4j)),f(P) = 7j, g(p) = (5+3j)
# P = ((10+7j), (5+8j)),f(P) = (10+7j), g(p) = (1+6j)
# P = ((10+8j), (3+0j)),f(P) = (5+7j), g(p) = (5+0j)
# P = ((10+9j), 3j),f(P) = (5+7j), g(p) = 5j
# P = ((10+10j), (3+5j)),f(P) = (10+7j), g(p) = (5+1j)
# 73

# %%
#  points except the pounts of target order  (a means c) and (b means d)
j = complex(0, 1)
p = 11
d = 1
a = 3 + 2j
b = 9 + 5j
R = []
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i + b)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y = (k ** 2).real % p + ((k ** 2).imag % p) * j
                if X == Y:
                  R.append((i, k))
                  break
            else:
                  continue
            break
# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope ** 2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points

target_order = 2
points_with_order = find_points_with_order(target_order)

print(f"Points with order not {target_order}:")
for P in R:
    if P not in points_with_order:
       count+=1
print(count)
f_prime_list = []
for P in R:
    if P not in points_with_order:
        f = 2*(3*P[0]**2 + 2*a*P[0] + d)      # 2f
        f_prime = complex(f.real % p, f.imag % p)
        print(f_prime)
        f_prime_list.append(f_prime)
total_sum = complex(0, 0)
for f_prime in f_prime_list:
    total_sum += f_prime.real
    v = (total_sum.real)%p +  (total_sum.imag %p)*j
print(v)

# %%
j = complex(0, 1)
p = 11
d = 1
a = 3 + 2j
b = 9 + 5j
R = []
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i + b)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y = (k ** 2).real % p + ((k ** 2).imag % p) * j
                if X == Y:
                  R.append((i, k))
                  break
            else:
                  continue
            break
# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope ** 2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
f_prime_list = []
target_order = 2
points_with_order = find_points_with_order(target_order)
print("points_with_order:" , points_with_order)
for P in R:
    if P not in points_with_order:
        f = 2*(3*P[0]**2 + 2*a*P[0] + d)      # 2f
        f_prime = complex(f.real % p, f.imag % p)
        f_prime_list.append(f_prime)
total_sum = complex(0, 0)
for f_prime in f_prime_list:
    total_sum += f_prime
    v = (total_sum.real)%p +  (total_sum.imag %p)*j
print(v)
# Out:
# points_with_order: [(5j, 0j), ((9+1j), 0j), ((10+3j), 0j)]
# (9+10j)

# %%
j = complex(0, 1)
p = 11
d = 1
a = 3 + 2j
b = 9 + 5j
R = []
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i + b)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y = (k ** 2).real % p + ((k ** 2).imag % p) * j
                if X == Y:
                  R.append((i, k))
                  break
            else:
                  continue
            break
# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope ** 2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
f_prime_list = []
f_o2_list = []
target_order = 2
points_with_order = find_points_with_order(target_order)
print("points_with_order_2:" , points_with_order)
for P in points_with_order:
  f_o2 = 3*P[0]**2 + 2*a*P[0] + d
  f_o2_prime= complex(f_o2.real % p, f_o2.imag % p)
  f_o2_list.append(f_o2_prime)
  print(f_o2_prime)
for P in R:
    if P not in points_with_order:
        f = 2*(3*P[0]**2 + 2*a*P[0] + d)      # 2f
        f_prime = complex(f.real % p, f.imag % p)
        f_prime_list.append(f_prime)
total_sum = complex(0, 0)
for f_prime in f_prime_list:
    total_sum += f_prime
    v = (total_sum.real)%p +  (total_sum.imag %p)*j
print("v:",v)
totall_sum = complex(0, 0)
for f_o2_prime in f_o2_list:
  totall_sum += f_o2_prime
  u = (totall_sum.real)%p +  (totall_sum.imag %p)*j
print("u:",u)
final = v+u
print("final:" ,final)
# Out:
# points_with_order_2: [(5j, 0j), ((9+1j), 0j), ((10+3j), 0j)]
# (5+8j)
# (5+8j)
# (3+7j)
# v: (9+10j)
# u: (2+1j)
# final: (11+11j)

# %%
j = complex(0, 1)
p = 11
d = 1
a = 3 + 2j
b = 9 + 5j
R = []
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i + b)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y = (k ** 2).real % p + ((k ** 2).imag % p) * j
                if X == Y:
                  R.append((i, k))
                  count+=1
                  break
            else:
                    continue
            break
g_list = []
for P in R:
    g = -2 * P[1]
    g_prime = (g.real % p) + (g.imag % p) * j
    g_dou_prime = (g_prime)**2
    g_triple_prime = g_dou_prime.real%p + (g_dou_prime.imag%p)*j
    g_list.append(g_triple_prime)
    print(f"g_prime={g_prime},g_dou-prime ={g_dou_prime} ,g_triple_prime={g_triple_prime}")

total_sum = complex(0, 0)
for g_triple_prime in g_list:
    total_sum += g_triple_prime
    u = total_sum.real%p + (total_sum.imag%p)*j
print("u:" , u)
# Out:
# g_prime=(5+10j),g_dou-prime =(-75+100j) ,g_triple_prime=(2+1j)
# g_prime=(5+7j),g_dou-prime =(-24+70j) ,g_triple_prime=(9+4j)
# g_prime=0j,g_dou-prime =0j ,g_triple_prime=0j
# g_prime=(9+2j),g_dou-prime =(77+36j) ,g_triple_prime=3j
# g_prime=(3+0j),g_dou-prime =(9+0j) ,g_triple_prime=(9+0j)
# g_prime=(7+0j),g_dou-prime =(49+0j) ,g_triple_prime=(5+0j)
# g_prime=(5+10j),g_dou-prime =(-75+100j) ,g_triple_prime=(2+1j)
# g_prime=(7+2j),g_dou-prime =(45+28j) ,g_triple_prime=(1+6j)
# g_prime=(3+2j),g_dou-prime =(5+12j) ,g_triple_prime=(5+1j)
# g_prime=(7+0j),g_dou-prime =(49+0j) ,g_triple_prime=(5+0j)
# g_prime=(3+4j),g_dou-prime =(-7+24j) ,g_triple_prime=(4+2j)
# g_prime=(5+4j),g_dou-prime =(9+40j) ,g_triple_prime=(9+7j)
# g_prime=(3+3j),g_dou-prime =18j ,g_triple_prime=7j
# g_prime=(1+5j),g_dou-prime =(-24+10j) ,g_triple_prime=(9+10j)
# g_prime=(9+4j),g_dou-prime =(65+72j) ,g_triple_prime=(10+6j)
# g_prime=(5+5j),g_dou-prime =50j ,g_triple_prime=6j
# g_prime=7j,g_dou-prime =(-49+0j) ,g_triple_prime=(6+0j)
# g_prime=(3+5j),g_dou-prime =(-16+30j) ,g_triple_prime=(6+8j)
# g_prime=(5+5j),g_dou-prime =50j ,g_triple_prime=6j
# g_prime=(3+8j),g_dou-prime =(-55+48j) ,g_triple_prime=4j
# g_prime=(5+0j),g_dou-prime =(25+0j) ,g_triple_prime=(3+0j)
# g_prime=(3+0j),g_dou-prime =(9+0j) ,g_triple_prime=(9+0j)
# g_prime=(7+8j),g_dou-prime =(-15+112j) ,g_triple_prime=(7+2j)
# g_prime=(1+2j),g_dou-prime =(-3+4j) ,g_triple_prime=(8+4j)
# g_prime=5j,g_dou-prime =(-25+0j) ,g_triple_prime=(8+0j)
# g_prime=(9+2j),g_dou-prime =(77+36j) ,g_triple_prime=3j
# g_prime=(5+1j),g_dou-prime =(24+10j) ,g_triple_prime=(2+10j)
# g_prime=(9+9j),g_dou-prime =162j ,g_triple_prime=8j
# g_prime=(5+5j),g_dou-prime =50j ,g_triple_prime=6j
# g_prime=3j,g_dou-prime =(-9+0j) ,g_triple_prime=(2+0j)
# g_prime=(3+9j),g_dou-prime =(-72+54j) ,g_triple_prime=(5+10j)
# g_prime=(1+6j),g_dou-prime =(-35+12j) ,g_triple_prime=(9+1j)
# g_prime=(9+10j),g_dou-prime =(-19+180j) ,g_triple_prime=(3+4j)
# g_prime=(3+0j),g_dou-prime =(9+0j) ,g_triple_prime=(9+0j)
# g_prime=(5+6j),g_dou-prime =(-11+60j) ,g_triple_prime=5j
# g_prime=(9+2j),g_dou-prime =(77+36j) ,g_triple_prime=3j
# g_prime=(1+6j),g_dou-prime =(-35+12j) ,g_triple_prime=(9+1j)
# g_prime=(1+9j),g_dou-prime =(-80+18j) ,g_triple_prime=(8+7j)
# g_prime=(5+1j),g_dou-prime =(24+10j) ,g_triple_prime=(2+10j)
# g_prime=(9+8j),g_dou-prime =(17+144j) ,g_triple_prime=(6+1j)
# g_prime=(5+0j),g_dou-prime =(25+0j) ,g_triple_prime=(3+0j)
# g_prime=(9+1j),g_dou-prime =(80+18j) ,g_triple_prime=(3+7j)
# g_prime=(3+7j),g_dou-prime =(-40+42j) ,g_triple_prime=(4+9j)
# g_prime=3j,g_dou-prime =(-9+0j) ,g_triple_prime=(2+0j)
# g_prime=5j,g_dou-prime =(-25+0j) ,g_triple_prime=(8+0j)
# g_prime=(3+3j),g_dou-prime =18j ,g_triple_prime=7j
# g_prime=(9+9j),g_dou-prime =162j ,g_triple_prime=8j
# g_prime=(5+6j),g_dou-prime =(-11+60j) ,g_triple_prime=5j
# g_prime=(7+9j),g_dou-prime =(-32+126j) ,g_triple_prime=(1+5j)
# g_prime=(5+6j),g_dou-prime =(-11+60j) ,g_triple_prime=5j
# g_prime=(5+8j),g_dou-prime =(-39+80j) ,g_triple_prime=(5+3j)
# g_prime=(7+0j),g_dou-prime =(49+0j) ,g_triple_prime=(5+0j)
# g_prime=(7+5j),g_dou-prime =(24+70j) ,g_triple_prime=(2+4j)
# g_prime=(7+3j),g_dou-prime =(40+42j) ,g_triple_prime=(7+9j)
# g_prime=7j,g_dou-prime =(-49+0j) ,g_triple_prime=(6+0j)
# g_prime=(9+3j),g_dou-prime =(72+54j) ,g_triple_prime=(6+10j)
# g_prime=(9+7j),g_dou-prime =(32+126j) ,g_triple_prime=(10+5j)
# g_prime=(5+10j),g_dou-prime =(-75+100j) ,g_triple_prime=(2+1j)
# g_prime=(3+8j),g_dou-prime =(-55+48j) ,g_triple_prime=4j
# g_prime=(9+9j),g_dou-prime =162j ,g_triple_prime=8j
# g_prime=0j,g_dou-prime =0j ,g_triple_prime=0j
# g_prime=(7+6j),g_dou-prime =(13+84j) ,g_triple_prime=(2+7j)
# g_prime=(1+5j),g_dou-prime =(-24+10j) ,g_triple_prime=(9+10j)
# g_prime=(1+5j),g_dou-prime =(-24+10j) ,g_triple_prime=(9+10j)
# g_prime=7j,g_dou-prime =(-49+0j) ,g_triple_prime=(6+0j)
# g_prime=3j,g_dou-prime =(-9+0j) ,g_triple_prime=(2+0j)
# g_prime=(3+6j),g_dou-prime =(-27+36j) ,g_triple_prime=(6+3j)
# g_prime=0j,g_dou-prime =0j ,g_triple_prime=0j
# g_prime=(5+3j),g_dou-prime =(16+30j) ,g_triple_prime=(5+8j)
# g_prime=(1+6j),g_dou-prime =(-35+12j) ,g_triple_prime=(9+1j)
# g_prime=(5+0j),g_dou-prime =(25+0j) ,g_triple_prime=(3+0j)
# g_prime=5j,g_dou-prime =(-25+0j) ,g_triple_prime=(8+0j)
# g_prime=(5+1j),g_dou-prime =(24+10j) ,g_triple_prime=(2+10j)
# u: 0j

# %%
# Out:
# (-75+100j)

# %%
j = complex(0, 1)
p = 11
d = 1
c = 3 + 2j
e = 9 + 5j
R = []
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i + b)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y = (k ** 2).real % p + ((k ** 2).imag % p) * j
                if X == Y:
                  R.append((i, k))
                  count+=1
                  break
            else:
                    continue
            break
for P in R:
    f = (3 * P[0] ** 2 + 2 * a * P[0] + d)*P[0]
    f_prime = (f.real % p) + (f.imag % p) * j
    print(f_prime)
# Out:
# (5+5j)
# (3+1j)
# (4+3j)
# (4+6j)
# (3+3j)
# (1+9j)
# (5+9j)
# (10+4j)
# (9+8j)
# 8j
# (2+1j)
# (5+4j)
# 0j
# (9+5j)
# (8+0j)
# (3+8j)
# (5+10j)
# (3+10j)
# (8+1j)
# (6+3j)
# (4+4j)
# (2+1j)
# 9j
# (9+10j)
# (5+7j)
# (8+5j)
# (9+8j)
# (5+3j)
# (6+4j)
# (7+1j)
# (1+3j)
# (10+3j)
# (1+5j)
# (2+1j)
# (10+5j)
# (5+9j)
# (1+10j)
# (4+2j)
# (10+9j)
# (2+0j)
# (1+1j)
# (6+7j)
# (10+8j)
# (4+2j)
# (10+4j)
# (6+7j)
# (3+4j)
# (10+9j)
# (6+0j)
# (8+5j)
# 10j
# (8+10j)
# (3+3j)
# (3+0j)
# (6+8j)
# (10+0j)
# (1+4j)
# (6+7j)
# 0j
# (9+5j)
# (4+0j)
# (1+2j)
# (4+2j)
# (5+4j)
# (3+9j)
# (5+2j)
# (8+4j)
# (9+2j)
# (5+4j)
# (7+8j)
# (5+0j)
# (9+5j)
# (8+5j)

# %%
j = complex(0, 1)
p = 11
d = 1
a = 3 + 2j
b = 9 + 5j
R = []
count = 0
for m in range(p):
    for n in range(p):
        i = m + n * j
        Z = (i ** 3 + a * i ** 2 + i + b)
        real_part = Z.real % p
        imaginary_part = Z.imag % p
        X = real_part + imaginary_part * 1j
        for k_m in range(p):
            for k_n in range(p):
                k = k_m + k_n * j
                Y = (k ** 2).real % p + ((k ** 2).imag % p) * j
                if X == Y:
                  R.append((i, k))
                  break
            else:
                  continue
            break
# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P

    if P == Q:
        num = 3 * P[0] ** 2 + 2 * a * P[0] + 1
        num_prime = complex(num.real % p, num.imag % p)
        den = complex(2 * P[1].real % p, 2 * P[1].imag % p)
        conj_den = den.real % p + (p - den.imag) % p * j
        ab = ((den.real) ** 2 + (den.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_prime = complex((conj_den * inverse).real % p, (conj_den * inverse).imag % p)
        slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    if P != Q:
        num = Q[1] - P[1]
        num_prime = num.real % p + num.imag % p * j

        den = Q[0] - P[0]
        den_prime = den.real % p + den.imag % p * j
        conj_den = den_prime.real % p + (p - den_prime.imag) % p * j
        ab = ((den_prime.real) ** 2 + (den_prime.imag) ** 2) % p

        def find_inverse(element, mod):
            if element == 0:
                return None

            # Apply the extended Euclidean algorithm
            a, b = mod, element
            x, y = 0, 1
            while b != 0:
                quotient = a // b
                a, b = b, a - quotient * b
                x, y = y, x - quotient * y

            # Ensure the inverse is positive
            inverse = x % mod
            if inverse < 0:
                inverse += mod

            return inverse

        # Test the function
        element = ab
        mod = p
        inverse = find_inverse(element, mod)

        if inverse is None:
            return None

        den_double = conj_den * inverse
        den_triple = den_double.real % p + den_double.imag % p * j
        slope_prime = num_prime * den_triple
        slope = slope_prime.real % p + slope_prime.imag % p * j

    Rx = slope ** 2 - a - P[0] - Q[0]
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]))
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

# Define a function to compute the order of a point on the curve
def point_order(P):
    if P is None:
        return 1
    Q = P
    order = 1
    while Q is not None:
        Q = point_addition(P, Q)
        order = order + 1
        if order > p + 1:
            return None
    return order

def find_points_with_order(order):
    points = []
    for P in R:
        P_order = point_order(P)
        if P_order == order:
            points.append(P)
    return points
f_prime_list = []
f_o2_list = []
target_order = 2
points_with_order = find_points_with_order(target_order)
print("points_with_order_2:" , points_with_order)
for P in points_with_order:
  f_o2 = (3*P[0]**2 + 2*a*P[0] + d)*P[0]
  f_o2_prime= complex(f_o2.real % p, f_o2.imag % p)
  f_o2_list.append(f_o2_prime)
  print(f_o2_prime)
for P in R:
    if P not in points_with_order:
        f = 2*(3*P[0]**2 + 2*a*P[0] + d) *P[0]     # 2f
        f_prime = complex(f.real % p, f.imag % p)
        f_prime_list.append(f_prime)
total_sum = complex(0, 0)
for f_prime in f_prime_list:
    total_sum += f_prime
    v = (total_sum.real)%p +  (total_sum.imag %p)*j
print("v:",v)
totall_sum = complex(0, 0)
for f_o2_prime in f_o2_list:
  totall_sum += f_o2_prime
  u = (totall_sum.real)%p +  (totall_sum.imag %p)*j
print("u:",u)
final = v+u
print("final:" ,final)
# Out:
# points_with_order_2: [(5j, 0j), ((9+1j), 0j), ((10+3j), 0j)]
# (4+3j)
# (4+0j)
# (9+2j)
# v: (5+6j)
# u: (6+5j)
# final: (11+11j)
