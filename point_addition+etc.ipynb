# %% [markdown]
# <a href="https://colab.research.google.com/github/shiz-107/Algebraic-Geometry-EC/blob/main/point_addition%2Betc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = 5
a = 2
b = 2
for i in range(p):
    X = (i**3 + a*i + b) % p
    for j in range(p):
        Y = (j**2) % p
        if X == Y:
            R = (i,j)
            print(R)
            break
# Out:
# (1, 0)
# (2, 2)
# (3, 0)
# (4, 2)

# %%
# Define the parameters of the elliptic curve
a = 1
b = 4
p = 5  # the field size


# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P
    if P[0] == Q[0] and P[1] != Q[1]:
        return None

    if P == Q:
        lam = ((3 * P[0] * P[0] + a) * pow(2 * P[1], p - 2, p)) % p
    else:
        lam = ((Q[1] - P[1]) * pow(Q[0] - P[0], p - 2, p)) % p

    Rx = (lam * lam - P[0] - Q[0]) % p
    Ry = (lam * (P[0] - Rx) - P[1]) % p

    return (Rx, Ry)
# Define a function to double a point on the curve
def point_doubling(P):
    if P is None:
        return None
    lam = ((3 * P[0] * P[0] + a) * pow(2 * P[1], p - 2, p)) % p
    Rx = (lam * lam - 2 * P[0]) % p
    Ry = (lam * (P[0] - Rx) - P[1]) % p
    return (Rx, Ry)

# Test point addition
P = (2, 2)
Q = (2, 2)
order = 1
while(Q!=None):
    Q = point_addition(P, Q)
    order = order+1
    if(order >130):
        print("Solution is not possible:::")
        break
    print(Q)
print("Order Is:" ,order)
# Out:
# (0, 2)
# (3, 3)
# (1, 4)
# (1, 1)
# (3, 2)
# (0, 3)
# (2, 3)
# None
# Order Is: 9

# %%
 n_prime = complex(n.real % p, n.imag % p)

# %%
# CORRECT:::
# Define the parameters of the elliptic curve E : y^2=x^3+Ax+x over F_431[j]
j = complex(0,1)
A = 208*j + 161
p = 431 # the field size


# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P
    if P[0] == Q[0] and P[1] != Q[1]:
        return None

    if P == Q:
        num = 3*P[0]**2 + 2*A*P[0] + 1
        num_prime = complex(num.real%p , num.imag%p)
        den = complex((2*P[1]).real%p,(2*P[1]).imag%p)
        conj_den = den.conjugate()
        ab = ((den.real)**2+(den.imag)**2)%p
        inverse =  108
        den_prime = conj_den*inverse
        den_double = (den_prime.real%p , den_prime.imag%p)
        slope = complex((num_prime*den_double).real%p , (num_prime*den_double).imag%p)
    else:
        num = Q[1] - P[1]
        num_prime = num.real%p + num.imag%p*j

        den = Q[0] - P[0]
        den_prime = den.real%p + den.imag%p*j
        conj_den = den.conjugate()
        ab = ((den_prime.real)**2+(den_prime.imag)**2)%p
        inverse =  1
        den_double = conj_den*inverse
        den_triple = den_prime.real%p + den_prime.imag%p*j
        slope_prime = num_prime*den_triple
        slope = slope_prime.real%p + slope_prime.imag%p*j



    Rx = slope**2 - A - P[0] - Q[0]
    Rx_prime = Rx.real%p + Rx.imag%p*j
    Ry = (slope * (P[0] - Rx_prime) - P[1])
    Ry_prime = Ry.real%p + Ry.imag%p*j
    return (Rx_prime, Ry_prime)

# Define a function to double a point on the curve
def point_doubling(P):
    if P is None:
        return None
    else:
        num = 3*P[0]**2 + 2*A*P[0] + 1
        num_prime = complex(num.real%p , num.imag%p)
        den = complex(2*P[1].real%p,2*P[1].imag%p)

        den_prime = complex((den.conjugate()*abs_inverse).real%p , (den.conjugate()*abs_inverse).imag%p)
        slope = complex((num_prime*den_prime).real%p , (num_prime*den_prime).imag%p)


    Rx = slope*slope - A- 2*P[0]
    Rx_prime = complex(Rx.real%p , Rx.imag%p)
    Ry = (slope * (P[0] - Rx_prime) - P[1])
    Ry_prime = complex(Ry.real%p , Ry.imag%p)
    return (Rx_prime, Ry_prime)


# Test point addition
P=(1j, (97+150j))
Q=(2j, (209+396j))
R=point_addition(P,Q)
print(R)
# Test point doubling
P = (1j, (138 + 9j))
R = point_doubling(P)
print(R)
# Out:
# ((401+284j), (83+420j))
# ((43+247j), (142+370j))

# %%
p = 11
denominator = 4

result = pow(denominator, -1,p)
print(result)
# Out:
# 3

# %%
j=complex(0,1)
p=5
s=17+23*j
print(s.real)
print(s.conjugate())
prime = s.real%p + s.imag%p*j
print(prime)
# Out:
# 17.0
# (17-23j)
# (2+3j)

# %%
import math

j = complex(0, 1)
p = 11
P = 7 + 2j
den = complex(2 * P.real % p, 2 * P.imag % p)
ab = abs(den) % p

# Calculate the modular inverse using the extended Euclidean algorithm
ab_inverse = pow(int(ab%p), -1 ,  p)
den_prime = complex((den*ab).real%p , (den*ab).imag%p)
print(den_prime)
# Out:
# (4+9j)

# %%
j = complex(0, 1)
p = 11
P = 7 + 2j
den = complex(2 * P.real % p, 2 * P.imag % p)
ab = abs(den) % p
print(ab)
# Out:
# 5.0

# %%
def find_inverse(element, mod):
    """
    Finds the inverse of an element in the finite field Z_mod.
    Returns the inverse if it exists, otherwise returns None.
    """
    if element == 0:
        return None

    # Apply the extended Euclidean algorithm
    a, b = mod, element
    x, y = 0, 1
    while b != 0:
        quotient = a // b
        a, b = b, a - quotient * b
        x, y = y, x - quotient * y

    # Ensure the inverse is positive
    inverse = x % mod
    if inverse < 0:
        inverse += mod

    return inverse

# Test the function
element = 261
mod =431
inverse = find_inverse(element, mod)
print("Inverse of", element, "in Z_", mod, ":", inverse)
# Out:
# Inverse of 261 in Z_ 431 : 180

# %%
# Define the parameters of the elliptic curve E : y^2=x^3+Ax+x over F_431[j]
j=complex(0,1)
A = 208*j + 161
p = 431 # the field size


# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P
    if P[0] == Q[0] and P[1] != Q[1]:
        return None

    if P == Q:
        den = complex((2*P[1]).real%p,(2*P[1]).imag%p)
        ab = ((den.real)**2 + (den.imag**2)) % p

    else:
        den = complex((Q[0] - P[0]).real%p , (Q[0] - P[0]).imag%p)
        ab = ((den.real)**2 + (den.imag)**2) % p
    print(ab)
point_addition(P, Q)
P=(1j, (97+150j))
Q=((300+346j), (99+62j))
R = point_addition(P, Q)
print(R)
# Out:
# 1.0
# 421.0
# None

# %%
j=complex(0,1)
p = 431 # the field size
def A(m,n):
       double = (m+n*j)**2
       double_prime = complex(double.real%p , double.imag%p)
       print(double_prime)
A(328,344)
# Out:
# (23+251j)

# %%
j=complex(0,1)
p = 431 # the field size
def A(m,n,o,p):
       mul = (m+n*j)*(o+p*j)
       mul_prime = mul.real%p + mul.imag%p*j
       print(mul_prime)
A(268,401,250,149)
# Out:
# (99+122j)

# %%
print(abs(2+3*j))
# Out:
# 3.605551275463989

# %%
p=431
j=complex(0,1)
A = 208*j + 161
def point_doubling(P):
    if P is None:
        return None
    num = 3*P[0]**2 + 2*A*P[0] + 1
    num_prime = complex(num.real%p, num.imag%p)
    den = complex(2*P[1].real%p, 2*P[1].imag%p)
    abs_inverse = pow((int(abs(den))**2), -1, p)
    den_prime = complex((den.conjugate() * abs_inverse).real % p, (den.conjugate() * abs_inverse).imag % p)
    slope = complex((num_prime * den_prime).real % p, (num_prime * den_prime).imag % p)

    Rx = slope*slope - P[0] - P[0]-A
    Rx_prime = complex(Rx.real % p, Rx.imag % p)
    Ry = (slope * (P[0] - Rx_prime) - P[1])
    Ry_prime = complex(Ry.real % p, Ry.imag % p)
    return (Rx_prime, Ry_prime)

P=(2j, (209+396j))
R=point_doubling(P)
print(R)
# Out:
# ((223+323j), (6+129j))

# %%
# CORRECT:::
# Define the parameters of the elliptic curve E : y^2=x^3+Ax+x over F_431[j]
j = complex(0,1)
A = 161 + 208*j
p = 431 # the field size


# Define a function to add two points on the curve
def point_addition(P, Q):
    if P is None:
        return Q
    if Q is None:
        return P
    if P[0] == Q[0] and P[1] != Q[1]:
        return None

    if P == Q:
        num = 3*P[0]**2 + 2*A*P[0] + 1
        num_prime = complex(num.real%p , num.imag%p)
        den = complex((2*P[1]).real%p,(2*P[1]).imag%p)
        conj_den = den.conjugate()
        ab = ((den.real)**2+(den.imag)**2)%p
        inverse = 352
        den_prime = conj_den*inverse
        den_double = (den_prime.real%p , den_prime.imag%p)
        slope = complex((num_prime*den_double).real%p , (num_prime*den_double).imag%p)
    else:
        num = Q[1] - P[1]
        num_prime = num.real%p + num.imag%p*j

        den = Q[0] - P[0]
        den_prime = den.real%p + den.imag%p*j
        conj_den = den_prime.real%p + (p-den_prime.imag)%p*j
        ab = ((den_prime.real)**2+(den_prime.imag)**2)%p
        inverse =  1
        den_double = conj_den*inverse
        den_triple = den_prime.real%p + den_prime.imag%p*j
        slope_prime = num_prime*den_triple
        slope = slope_prime.real%p + slope_prime.imag%p*j


    Rx = slope**2 - A - P[0] - Q[0]
    Rx_prime = Rx.real%p + Rx.imag%p*j
    Ry = -(P[1] + slope * (Rx_prime - P[0]) )
    Ry_prime = Ry.real%p + Ry.imag%p*j
    return (Rx_prime, Ry_prime)

# Define a function to double a point on the curve
def point_doubling(P):
    if P is None:
        return None
    else:
        num = 3*P[0]**2 + 2*A*P[0] + 1
        num_prime = complex(num.real%p , num.imag%p)
        den = complex(2*P[1].real%p,2*P[1].imag%p)
        conj_den = den.real%p + (p-den.imag)%p*j
        ab = ((den.real)**2+(den.imag)**2)%p
        abs_inverse =  352
        den_prime = complex((conj_den*abs_inverse).real%p , (conj_den*abs_inverse).imag%p)
        slope = complex((num_prime*den_prime).real%p , (num_prime*den_prime).imag%p)


    Rx = slope**2 - A - 2*P[0]
    Rx_prime = complex(Rx.real%p , Rx.imag%p)
    Ry = -(P[1] + slope * (Rx_prime - P[0]) )
    Ry_prime = complex(Ry.real%p , Ry.imag%p)
    return (Rx_prime, Ry_prime)


# Test point addition
P=(1j, (97+150j))
Q=(2j, (209+396j))
R=point_addition(P,Q)
print(R)
# Test point doubling
P=(56+321*j, 173+303*j)
R = point_doubling(P)
print(R)
# Out:
# ((401+284j), (83+420j))
# ((223+255j), (326+136j))
